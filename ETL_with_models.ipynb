# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
base_columns = [
    'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
    'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
    'TOV', 'PF', 'PTS', 'PLUS_MINUS',
    'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
    'E_NET_RATING', 'NET_RATING', 'AST_PCT', 'AST_TOV',
    'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'REB_PCT',
    'E_TM_TOV_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT',
    'USG_PCT', 'E_USG_PCT', 'E_PACE', 'PACE',
    'PACE_PER40', 'POSS', 'PIE'
]

def calculate_fg_pct(FGM, FGA):
    return FGM / FGA

def calculate_fg3_pct(FG3M, FG3A):
    return FG3M / FG3A

def calculate_ft_pct(FTM, FTA):
    return FTM / FTA

def calculate_ast_to_ratio(AST, TOV):
    # Assist to Turnover ratio
    return AST / TOV

def calculate_efg_pct(FGM, FG3M, FGA):
    # (FGM + 0.5 * 3PM) / FGA
    return (FGM + 0.5 * FG3M) / FGA

def calculate_ts_pct(PTS, FGA, FTA):
    # Points / (2 * (FGA + 0.44 * FTA))
    return PTS / (2 * (FGA + 0.44 * FTA))

def calculate_reb_ratio(OREB, DREB):
    # Total rebound ratio
    return (OREB + DREB) / DREB  # or you could just divide OREB by DREB if you want offensive rebounding ratio

def calculate_ast_pct(AST, POSS):
    return AST / POSS

def calculate_oreb_pct(OREB, POSS):
    return OREB / POSS

def calculate_dreb_pct(DREB, POSS):
    return DREB / POSS

def calculate_reb_pct(REB, POSS):
    return REB / POSS

def calculate_tm_tov_pct(TOV, POSS):
    return TOV / POSS

# ### Example 
# config = ProcessingConfig(
#     cumulative_columns=[
#         'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
#         'OREB', 'DREB', 'AST', 'TOV', 'PTS'
#     ],
#     derived_metrics=derived_metrics,
#     difference_columns=['FG_PCT', 'FG3_PCT', 'FT_PCT', 'AST_TO_RATIO', 
#                        'EFG_PCT', 'TS_PCT', 'REB_RATIO']

# %%
from Preprocess import ProcessingConfig, NBADataProcessor, DerivedMetric

derived_metrics = {
    'FG_PCT': DerivedMetric(
        columns=['FGM', 'FGA'],
        formula=calculate_fg_pct
    ),
    'FG3_PCT': DerivedMetric(
        columns=['FG3M', 'FG3A'],
        formula=calculate_fg3_pct
    ),
    'FT_PCT': DerivedMetric(
        columns=['FTM', 'FTA'],
        formula=calculate_ft_pct
    ),
    'AST_TO_RATIO': DerivedMetric(
        columns=['AST', 'TOV'],
        formula=calculate_ast_to_ratio
    ),
    'EFG_PCT': DerivedMetric(
        columns=['FGM', 'FG3M', 'FGA'],
        formula=calculate_efg_pct
    ),
    'TS_PCT': DerivedMetric(
        columns=['PTS', 'FGA', 'FTA'],
        formula=calculate_ts_pct
    ),
    'REB_RATIO': DerivedMetric(
        columns=['OREB', 'DREB'],
        formula=calculate_reb_ratio
    ),
    'AST_PCT': DerivedMetric(
        columns=['AST', 'POSS'],
        formula=calculate_ast_pct
    ),
    'AST_TOV': DerivedMetric(
        columns=['AST', 'TOV'],
        formula=calculate_ast_to_ratio
    ),
    'OREB_PCT': DerivedMetric(
        columns=['OREB', 'POSS'],
        formula=calculate_oreb_pct
    ),
    'DREB_PCT': DerivedMetric(
        columns=['DREB', 'POSS'],
        formula=calculate_dreb_pct
    ),
    'REB_PCT': DerivedMetric(
        columns=['REB', 'POSS'],
        formula=calculate_reb_pct
    ),
    'TM_TOV_PCT': DerivedMetric(
        columns=['TOV', 'POSS'],
        formula=calculate_tm_tov_pct
    )
}

cumu_config = ProcessingConfig(
    rolling_columns=[
    'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
    'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
    'TOV', 'PF', 'PTS', 'PLUS_MINUS',
    'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
    'E_NET_RATING', 'NET_RATING', 'E_PACE', 'PACE',
    'PACE_PER40', 'POSS', 'PIE'
    ],
    cumulative_columns=[
    'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
    'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
    'TOV', 'PF', 'PTS', 'PLUS_MINUS',
    'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
    'E_NET_RATING', 'NET_RATING', 'E_PACE', 'PACE',
    'PACE_PER40', 'POSS', 'PIE'
    ],
    derived_metrics=derived_metrics,
    difference_columns= ['FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
    'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
    'TOV', 'PF', 'PTS', 'PLUS_MINUS',
    'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
    'E_NET_RATING', 'NET_RATING', 'E_PACE', 'PACE',
    'PACE_PER40', 'POSS', 'PIE','FG_PCT', 'FG3_PCT', 'FT_PCT', 'AST_TO_RATIO', 'EFG_PCT', 'TS_PCT', 'REB_RATIO', 'AST_PCT', 'AST_TOV', 'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'TM_TOV_PCT','HOME_ELO_PRE','AWAY_ELO_PRE'],

    initial_elo=1500,
    k_factor=20,
    home_advantage=100,
    elo_width=400
)

processor = NBADataProcessor(cumu_config)
processed_data = processor.load_and_merge_data('Advanced_box_scores_2023.csv',
                                        'traditional_box_scores_2023.csv')
df = processor.add_game_context(processed_data)

# %%
cumulative_columns=[
    'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
    'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
    'TOV', 'PF', 'PTS', 'PLUS_MINUS',
    'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
    'E_NET_RATING', 'NET_RATING', 'E_PACE', 'PACE',
    'PACE_PER40', 'POSS', 'PIE'
    ]

df = df.copy()

df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
df = df.sort_values(by=['TEAM_ID', 'GAME_DATE']).reset_index(drop=True)
# Out:
#       Unnamed: 0_x  SEASON_ID     TEAM_ID               TEAM_NAME   GAME_ID  \
# 0                0      22023  1610612756            Phoenix Suns  22300062
# 1                1      22023  1610612744   Golden State Warriors  22300062
# 2                3      22023  1610612747      Los Angeles Lakers  22300061
# 3                2      22023  1610612743          Denver Nuggets  22300061
# 4                4      22023  1610612748              Miami Heat  22300068
# ...            ...        ...         ...                     ...       ...
# 2455          2459      22023  1610612757  Portland Trail Blazers  22301200
# 2456          2458      22023  1610612762               Utah Jazz  22301198
# 2457          2449      22023  1610612744   Golden State Warriors  22301198
# 2458          2450      22023  1610612761         Toronto Raptors  22301189
# 2459          2456      22023  1610612748              Miami Heat  22301189
#
#        GAME_DATE      MATCHUP  WL  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# 0     2023-10-24    PHX @ GSW   1   42   95   0.442    11    33    0.333   13
# 1     2023-10-24  GSW vs. PHX   0   36  101   0.356    10    43    0.233   22
# 2     2023-10-24    LAL @ DEN   0   41   90   0.456    10    29    0.345   15
# 3     2023-10-24  DEN vs. LAL   1   48   91   0.527    14    34    0.412    9
# 4     2023-10-25  MIA vs. DET   1   37   92   0.402     8    22    0.364   21
# ...          ...          ...  ..  ...  ...     ...   ...   ...      ...  ...
# 2455  2024-04-14    POR @ SAC   0   31   98   0.316     7    45    0.156   13
# 2456  2024-04-14    UTA @ GSW   0   46   89   0.517    14    34    0.412   10
# 2457  2024-04-14  GSW vs. UTA   1   45   94   0.479    14    43    0.326   19
# 2458  2024-04-14    TOR @ MIA   0   38   90   0.422     9    34    0.265   18
# 2459  2024-04-14  MIA vs. TOR   1   46   87   0.529     9    36    0.250   17
#
#       FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0      17   0.765    17    43   60   23    5    7   19  22  108           4
# 1      28   0.786    18    31   49   19   11    6   11  23  104          -4
# 2      20   0.750    13    31   44   23    5    4   12  18  107         -12
# 3      12   0.750     9    33   42   29    9    6   12  15  119          12
# 4      26   0.808    16    32   48   22   11    3    7  18  103           1
# ...   ...     ...   ...   ...  ...  ...  ...  ...  ...  ..  ...         ...
# 2455   17   0.765    23    31   54   18   11    2   18  19   82         -39
# 2456   16   0.625    14    34   48   22    6    5   20  20  116          -7
# 2457   23   0.826    12    30   42   35   10    6    9  14  123           7
# 2458   21   0.857    13    28   41   23    6    3   19  21  103         -15
# 2459   19   0.895    13    33   46   29   13    7   19  16  118          15
#
#       Unnamed: 0_y  E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  \
# 0                0         103.4       106.9          97.8       102.0
# 1                1          97.8       102.0         103.4       106.9
# 2                2         109.4       111.5         119.9       125.3
# 3                3         119.9       125.3         109.4       111.5
# 4                4         109.1       108.4         103.4       106.3
# ...            ...           ...         ...           ...         ...
# 2455          2455          81.6        82.8         121.1       122.2
# 2456          2456         113.7       116.0         121.6       123.0
# 2457          2457         121.6       123.0         113.7       116.0
# 2458          2458          97.9       104.0         116.4       116.8
# 2459          2459         116.4       116.8          97.9       104.0
#
#       E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  AST_RATIO  OREB_PCT  \
# 0              5.6         5.0    0.548     1.21       15.9     0.396
# 1             -5.6        -5.0    0.528     1.73       13.3     0.358
# 2            -10.5       -13.8    0.561     1.92       17.2     0.346
# 3             10.5        13.8    0.604     2.42       21.1     0.289
# 4              5.6         2.2    0.595     3.14       16.6     0.298
# ...            ...         ...      ...      ...        ...       ...
# 2455         -39.5       -39.4    0.581     1.00       12.7     0.412
# 2456          -8.0        -7.0    0.478     1.10       15.9     0.333
# 2457           8.0         7.0    0.778     3.89       23.6     0.294
# 2458         -18.5       -12.8    0.605     1.21       16.3     0.352
# 2459          18.5        12.8    0.630     1.53       20.2     0.333
#
#       DREB_PCT  REB_PCT  E_TM_TOV_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  \
# 0        0.642    0.533        18.185        18.8    0.500   0.527      1.0
# 1        0.604    0.467        10.346        10.8    0.406   0.459      1.0
# 2        0.711    0.515        12.270        12.5    0.511   0.541      1.0
# 3        0.654    0.485        12.087        12.6    0.604   0.618      1.0
# 4        0.625    0.460         7.412         7.4    0.446   0.498      1.0
# ...        ...      ...           ...         ...      ...     ...      ...
# 2455     0.681    0.522        17.914        18.2    0.352   0.389      1.0
# 2456     0.706    0.525        19.600        20.0    0.596   0.604      1.0
# 2457     0.667    0.475         8.900         9.0    0.553   0.591      1.0
# 2458     0.667    0.490        18.054        19.2    0.472   0.519      1.0
# 2459     0.648    0.510        18.745        18.8    0.580   0.619      1.0
#
#       E_USG_PCT  E_PACE   PACE  PACE_PER40  POSS    PIE home_away
# 0         0.198  105.40  101.5       84.58   101  0.564      away
# 1         0.198  105.40  101.5       84.58   102  0.436      home
# 2         0.199   98.54   95.5       79.58    96  0.421      away
# 3         0.196   98.54   95.5       79.58    95  0.579      home
# 4         0.201   96.52   95.5       79.58    95  0.507      home
# ...         ...     ...    ...         ...   ...    ...       ...
# 2455      0.199  100.18   99.0       82.50    99  0.269      away
# 2456      0.195  101.58  100.0       83.33   100  0.429      away
# 2457      0.200  101.58  100.0       83.33   100  0.571      home
# 2458      0.198  103.30  100.0       83.33    99  0.369      away
# 2459      0.196  103.30  100.0       83.33   101  0.631      home
#
# [2460 rows x 52 columns]

# %%
processed_data[processed_data['TEAM_NAME_home'] == 'Denver Nuggets'][['FGM_home','FGM_cumulative_home','FGM_rolling_home']]
# Out:
#      FGM_home  FGM_cumulative_home  FGM_rolling_home
# 245        48                  NaN               NaN
# 246        47                142.0         47.333333
# 247        49                227.0         45.400000
# 248        42                276.0         45.600000
# 249        51                318.0         45.800000
# 250        41                369.0         45.400000
# 251        39                452.0         45.000000
# 252        50                693.0         40.400000
# 253        48                787.0         42.000000
# 254        38                975.0         46.400000
# 255        47               1099.0         42.800000
# 256        42               1146.0         42.400000
# 257        49               1188.0         42.600000
# 258        40               1370.0         44.800000
# 259        55               1410.0         44.400000
# 260        36               1465.0         45.600000
# 261        41               1501.0         43.000000
# 262        48               1590.0         44.000000
# 263        47               1638.0         45.600000
# 264        50               1722.0         44.200000
# 265        46               1772.0         46.000000
# 266        37               2026.0         41.600000
# 267        44               2063.0         40.000000
# 268        46               2144.0         39.200000
# 269        42               2190.0         39.600000
# 270        35               2353.0         41.800000
# 271        56               2388.0         39.600000
# 272        46               2537.0         44.000000
# 273        36               2583.0         46.000000
# 274        41               2673.0         45.800000
# 275        45               2714.0         44.000000
# 276        55               2759.0         44.400000
# 277        52               2814.0         46.200000
# 278        45               3034.0         44.000000
# 279        48               3120.0         42.800000
# 280        38               3168.0         42.600000
# 281        35               3206.0         42.800000
# 282        50               3241.0         41.400000
# 283        43               3291.0         42.400000
# 284        53               3370.0         40.400000
# 285        46               3469.0         45.600000

# %%
# processed_data.to_csv('preprocess_output.csv')

# %%
1487.198700+100

# %%
atl = processed_data.loc[processed_data['TEAM_NAME_home'] == 'Miami Heat']
atl[['PTS_home', 'PTS_cumulative_home']]
atl

# %% [markdown]
# # This is where i am testing to see if i can get this right

# %%
from Preprocess import ProcessingConfig, NBADataProcessor, DerivedMetric

# Define your calculation functions (keep these the same)
def calculate_fg_pct(FGM, FGA):
    return FGM / FGA

def calculate_fg3_pct(FG3M, FG3A):
    return FG3M / FG3A

def calculate_ft_pct(FTM, FTA):
    return FTM / FTA

def calculate_ast_to_ratio(AST, TOV):
    return AST / TOV

def calculate_efg_pct(FGM, FG3M, FGA):
    return (FGM + 0.5 * FG3M) / FGA

def calculate_ts_pct(PTS, FGA, FTA):
    return PTS / (2 * (FGA + 0.44 * FTA))

def calculate_reb_ratio(OREB, DREB):
    return (OREB + DREB) / DREB

def calculate_ast_pct(AST, POSS):
    return AST / POSS

def calculate_oreb_pct(OREB, POSS):
    return OREB / POSS

def calculate_dreb_pct(DREB, POSS):
    return DREB / POSS

def calculate_reb_pct(REB, POSS):
    return REB / POSS

def calculate_tm_tov_pct(TOV, POSS):
    return TOV / POSS

# Define derived metrics (same as before)
derived_metrics = {
    'FG_PCT': DerivedMetric(
        columns=['FGM', 'FGA'],
        formula=calculate_fg_pct
    ),
    'FG3_PCT': DerivedMetric(
        columns=['FG3M', 'FG3A'],
        formula=calculate_fg3_pct
    ),
    'FT_PCT': DerivedMetric(
        columns=['FTM', 'FTA'],
        formula=calculate_ft_pct
    ),
    'AST_TO_RATIO': DerivedMetric(
        columns=['AST', 'TOV'],
        formula=calculate_ast_to_ratio
    ),
    'EFG_PCT': DerivedMetric(
        columns=['FGM', 'FG3M', 'FGA'],
        formula=calculate_efg_pct
    ),
    'TS_PCT': DerivedMetric(
        columns=['PTS', 'FGA', 'FTA'],
        formula=calculate_ts_pct
    ),
    'REB_RATIO': DerivedMetric(
        columns=['OREB', 'DREB'],
        formula=calculate_reb_ratio
    ),
    'AST_PCT': DerivedMetric(
        columns=['AST', 'POSS'],
        formula=calculate_ast_pct
    ),
    'AST_TOV': DerivedMetric(
        columns=['AST', 'TOV'],
        formula=calculate_ast_to_ratio
    ),
    'OREB_PCT': DerivedMetric(
        columns=['OREB', 'POSS'],
        formula=calculate_oreb_pct
    ),
    'DREB_PCT': DerivedMetric(
        columns=['DREB', 'POSS'],
        formula=calculate_dreb_pct
    ),
    'REB_PCT': DerivedMetric(
        columns=['REB', 'POSS'],
        formula=calculate_reb_pct
    ),
    'TM_TOV_PCT': DerivedMetric(
        columns=['TOV', 'POSS'],
        formula=calculate_tm_tov_pct
    )
}

# FIXED CONFIGURATION:
# 1. Only raw counting stats in rolling/cumulative (not ratios/percentages)
# 2. Difference columns include both base stats and derived metrics
# 3. All processing will create differences, then remove home/away columns

base_counting_stats = [
    'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
    'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
    'TOV', 'PF', 'PTS', 'PLUS_MINUS',
    'POSS', 'PIE'
]

# Advanced stats that can be accumulated (excluding PIE and percentage-based metrics)
advanced_counting_stats = [
    'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
    'E_NET_RATING', 'NET_RATING', 'E_PACE', 'PACE', 'PACE_PER40'
]

# All columns that should be processed (raw stats only)
all_processable_columns = base_counting_stats + advanced_counting_stats

# All derived metric names
derived_metric_names = list(derived_metrics.keys())

# ELO columns
elo_columns = ['HOME_ELO_PRE', 'AWAY_ELO_PRE']

# ALL columns that we want differences for (both base stats and derived metrics)
all_difference_columns = all_processable_columns + derived_metric_names + elo_columns

cumu_config = ProcessingConfig(
    # Only accumulate raw counting stats (not ratios/percentages)
    rolling_columns=all_processable_columns,
    cumulative_columns=all_processable_columns,
    
    # Calculate derived metrics from cumulative stats
    derived_metrics=derived_metrics,
    
    # Create differences for everything: base stats, derived metrics, and ELO
    difference_columns=all_difference_columns,
    
    # ELO settings
    initial_elo=1500,
    k_factor=20,
    home_advantage=100,
    elo_width=400
)

# Process the data
processor = NBADataProcessor(cumu_config)
processed_data = processor.load_and_merge_data('Advanced_box_scores_2023.csv',
                                              'traditional_box_scores_2023.csv')
df = processor.add_game_context(processed_data)

# %%
df = df.copy()

df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
df = df.sort_values(by=['TEAM_ID', 'GAME_DATE']).reset_index(drop=True)

group = df.groupby('TEAM_ID')
DF = []

for team_id, group_df in group:
    temp_df = group_df.copy()
    temp_df = temp_df.sort_values(by='GAME_DATE')

    # Calculate cumulative stats and rolling stats
    for col in all_processable_columns:
        if col in temp_df.columns:
            temp_df[f'{col}_cumulative'] = temp_df[col].cumsum().shift(1)
            temp_df[f'{col}_rolling'] = temp_df[col].shift(1).rolling(window=5, min_periods=1).mean()

    # Append after processing all columns
    DF.append(temp_df)

# Combine all teams back together
final_df = pd.concat(DF, ignore_index=True)

# %%
final_df
# Out:
#       Unnamed: 0_x  SEASON_ID     TEAM_ID          TEAM_NAME   GAME_ID  \
# 0               14      22023  1610612737      Atlanta Hawks  22300063
# 1               51      22023  1610612737      Atlanta Hawks  22300079
# 2               73      22023  1610612737      Atlanta Hawks  22300097
# 3               85      22023  1610612737      Atlanta Hawks  22300104
# 4              128      22023  1610612737      Atlanta Hawks  22300117
# ...            ...        ...         ...                ...       ...
# 2455          2343      22023  1610612766  Charlotte Hornets  22301135
# 2456          2358      22023  1610612766  Charlotte Hornets  22301144
# 2457          2383      22023  1610612766  Charlotte Hornets  22301159
# 2458          2415      22023  1610612766  Charlotte Hornets  22301173
# 2459          2452      22023  1610612766  Charlotte Hornets  22301187
#
#       GAME_DATE      MATCHUP  WL  FGM  FGA  ...  E_NET_RATING_cumulative  \
# 0    2023-10-25    ATL @ CHA   0   39   93  ...                      NaN
# 1    2023-10-27  ATL vs. NYK   0   42   87  ...                     -8.8
# 2    2023-10-29    ATL @ MIL   1   47   93  ...                    -13.2
# 3    2023-10-30  ATL vs. MIN   1   48   86  ...                      1.9
# 4    2023-11-01  ATL vs. WAS   1   46   92  ...                     15.4
# ...         ...          ...  ..  ...  ...  ...                      ...
# 2455 2024-04-07  CHA vs. OKC   0   45   83  ...                   -770.9
# 2456 2024-04-09  CHA vs. DAL   0   39   89  ...                   -772.3
# 2457 2024-04-10    CHA @ ATL   1   40   79  ...                   -799.5
# 2458 2024-04-12    CHA @ BOS   0   32   76  ...                   -795.7
# 2459 2024-04-14    CHA @ CLE   1   46   91  ...                   -830.7
#
#       E_NET_RATING_rolling  NET_RATING_cumulative  NET_RATING_rolling  \
# 0                      NaN                    NaN                 NaN
# 1                -8.800000                   -5.8           -5.800000
# 2                -6.600000                  -13.6           -6.800000
# 3                 0.633333                    0.7            0.233333
# 4                 3.850000                   17.5            4.375000
# ...                    ...                    ...                 ...
# 2455             -7.300000                 -825.3           -8.620000
# 2456             -4.100000                 -829.7           -5.500000
# 2457             -5.940000                 -856.7           -8.040000
# 2458             -2.540000                 -855.7           -4.600000
# 2459             -9.580000                 -887.4          -10.300000
#
#       E_PACE_cumulative  E_PACE_rolling  PACE_cumulative  PACE_rolling  \
# 0                   NaN             NaN              NaN           NaN
# 1                105.98      105.980000           104.00    104.000000
# 2                211.74      105.870000           211.00    105.500000
# 3                317.98      105.993333           314.00    104.666667
# 4                418.74      104.685000           412.00    103.000000
# ...                 ...             ...              ...           ...
# 2455            7655.93       96.472000          7528.14     94.800000
# 2456            7756.75       97.784000          7624.64     95.000000
# 2457            7858.27       99.108000          7725.14     96.400000
# 2458            7957.13       99.792000          7823.14     97.300000
# 2459            8057.83      100.236000          7923.64     98.400000
#
#       PACE_PER40_cumulative  PACE_PER40_rolling
# 0                       NaN                 NaN
# 1                     86.67           86.670000
# 2                    175.84           87.920000
# 3                    261.67           87.223333
# 4                    343.34           85.835000
# ...                     ...                 ...
# 2455                6273.46           79.002000
# 2456                6353.88           79.170000
# 2457                6437.63           80.336000
# 2458                6519.30           81.086000
# 2459                6603.05           82.002000
#
# [2460 rows x 106 columns]

# %%
import numpy as np

def calculate_fg_pct(FGM, FGA):
    return FGM / FGA

def calculate_fg3_pct(FG3M, FG3A):
    return FG3M / FG3A

def calculate_ft_pct(FTM, FTA):
    return FTM / FTA

def calculate_ast_to_ratio(AST, TOV):
    return AST / TOV

def calculate_efg_pct(FGM, FG3M, FGA):
    return (FGM + 0.5 * FG3M) / FGA

def calculate_ts_pct(PTS, FGA, FTA):
    return PTS / (2 * (FGA + 0.44 * FTA))

def calculate_reb_ratio(OREB, DREB):
    return (OREB + DREB) / DREB

def calculate_ast_pct(AST, POSS):
    return AST / POSS

def calculate_oreb_pct(OREB, POSS):
    return OREB / POSS

def calculate_dreb_pct(DREB, POSS):
    return DREB / POSS

def calculate_reb_pct(REB, POSS):
    return REB / POSS

def calculate_tm_tov_pct(TOV, POSS):
    return TOV / POSS

# Define derived metrics configuration
derived_metrics = {
    'FG_PCT': {
        'columns': ['FGM', 'FGA'],
        'formula': calculate_fg_pct
    },
    'FG3_PCT': {
        'columns': ['FG3M', 'FG3A'],
        'formula': calculate_fg3_pct
    },
    'FT_PCT': {
        'columns': ['FTM', 'FTA'],
        'formula': calculate_ft_pct
    },
    'AST_TO_RATIO': {
        'columns': ['AST', 'TOV'],
        'formula': calculate_ast_to_ratio
    },
    'EFG_PCT': {
        'columns': ['FGM', 'FG3M', 'FGA'],
        'formula': calculate_efg_pct
    },
    'TS_PCT': {
        'columns': ['PTS', 'FGA', 'FTA'],
        'formula': calculate_ts_pct
    },
    'REB_RATIO': {
        'columns': ['OREB', 'DREB'],
        'formula': calculate_reb_ratio
    },
    'AST_PCT': {
        'columns': ['AST', 'POSS'],
        'formula': calculate_ast_pct
    },
    'AST_TOV': {
        'columns': ['AST', 'TOV'],
        'formula': calculate_ast_to_ratio
    },
    'OREB_PCT': {
        'columns': ['OREB', 'POSS'],
        'formula': calculate_oreb_pct
    },
    'DREB_PCT': {
        'columns': ['DREB', 'POSS'],
        'formula': calculate_dreb_pct
    },
    'REB_PCT': {
        'columns': ['REB', 'POSS'],
        'formula': calculate_reb_pct
    },
    'TM_TOV_PCT': {
        'columns': ['TOV', 'POSS'],
        'formula': calculate_tm_tov_pct
    }
}

for metric_name, metric_info in derived_metrics.items():
    columns_needed = metric_info['columns']
    formula = metric_info['formula']
    
    # For cumulative metrics
    cumulative_cols = [f'{col}_cumulative' for col in columns_needed]
    if all(col in final_df.columns for col in cumulative_cols):
        # Create a dictionary of column_name -> column_data
        col_data = {original_col: final_df[cum_col] 
                   for original_col, cum_col in zip(columns_needed, cumulative_cols)}
        
        # Call the formula with keyword arguments
        final_df[f'{metric_name}_cumulative'] = formula(**col_data)
        print(f"✅ Calculated {metric_name}_cumulative (dynamic)")
    
    # For rolling metrics
    rolling_cols = [f'{col}_rolling' for col in columns_needed]
    if all(col in final_df.columns for col in rolling_cols):
        # Create a dictionary of column_name -> column_data
        col_data = {original_col: final_df[roll_col] 
                   for original_col, roll_col in zip(columns_needed, rolling_cols)}
        
        # Call the formula with keyword arguments
        final_df[f'{metric_name}_rolling'] = formula(**col_data)
        print(f"✅ Calculated {metric_name}_rolling (dynamic)")

print("\nDerived metrics calculation complete!")

# Verify what we created
derived_cumulative_cols = [col for col in final_df.columns if col.endswith('_cumulative') and any(metric in col for metric in derived_metrics.keys())]
derived_rolling_cols = [col for col in final_df.columns if col.endswith('_rolling') and any(metric in col for metric in derived_metrics.keys())]

print(f"\nCreated {len(derived_cumulative_cols)} cumulative derived metrics:")
for col in derived_cumulative_cols:
    print(f"  - {col}")

print(f"\nCreated {len(derived_rolling_cols)} rolling derived metrics:")
for col in derived_rolling_cols:
    print(f"  - {col}")

# Handle division by zero and infinite values (optional but recommended)
print("\nCleaning up infinite and NaN values...")

# Replace infinite values with NaN
final_df = final_df.replace([np.inf, -np.inf], np.nan)

# Check for any issues
problematic_cols = []
for col in final_df.columns:
    if col.endswith('_cumulative') or col.endswith('_rolling'):
        if final_df[col].isna().all():
            problematic_cols.append(col)
        elif final_df[col].isin([np.inf, -np.inf]).any():
            problematic_cols.append(col)

if problematic_cols:
    print(f"⚠️  Warning: These columns have issues: {problematic_cols}")
else:
    print("✅ All derived metrics calculated successfully!")
# Out:
# ✅ Calculated FG_PCT_cumulative (dynamic)
# ✅ Calculated FG_PCT_rolling (dynamic)
# ✅ Calculated FG3_PCT_cumulative (dynamic)
# ✅ Calculated FG3_PCT_rolling (dynamic)
# ✅ Calculated FT_PCT_cumulative (dynamic)
# ✅ Calculated FT_PCT_rolling (dynamic)
# ✅ Calculated AST_TO_RATIO_cumulative (dynamic)
# ✅ Calculated AST_TO_RATIO_rolling (dynamic)
# ✅ Calculated EFG_PCT_cumulative (dynamic)
# ✅ Calculated EFG_PCT_rolling (dynamic)
# ✅ Calculated TS_PCT_cumulative (dynamic)
# ✅ Calculated TS_PCT_rolling (dynamic)
# ✅ Calculated REB_RATIO_cumulative (dynamic)
# ✅ Calculated REB_RATIO_rolling (dynamic)
# ✅ Calculated AST_PCT_cumulative (dynamic)
# ✅ Calculated AST_PCT_rolling (dynamic)
# ✅ Calculated AST_TOV_cumulative (dynamic)
# ✅ Calculated AST_TOV_rolling (dynamic)
# ✅ Calculated OREB_PCT_cumulative (dynamic)
# ✅ Calculated OREB_PCT_rolling (dynamic)
# ✅ Calculated DREB_PCT_cumulative (dynamic)
# ✅ Calculated DREB_PCT_rolling (dynamic)
# ✅ Calculated REB_PCT_cumulative (dynamic)
# ✅ Calculated REB_PCT_rolling (dynamic)
# ✅ Calculated TM_TOV_PCT_cumulative (dynamic)
# ✅ Calculated TM_TOV_PCT_rolling (dynamic)
#
# Derived metrics calculation complete!
#
# Created 13 cumulative derived metrics:
#   - FG_PCT_cumulative
#   - FG3_PCT_cumulative
#   - FT_PCT_cumulative
#   - AST_TO_RATIO_cumulative
#   - EFG_PCT_cumulative
#   - TS_PCT_cumulative
#   - REB_RATIO_cumulative
#   - AST_PCT_cumulative
#   - AST_TOV_cumulative
#   - OREB_PCT_cumulative
#   - DREB_PCT_cumulative
#   - REB_PCT_cumulative
#   - TM_TOV_PCT_cumulative
#
# Created 13 rolling derived metrics:
#   - FG_PCT_rolling
#   - FG3_PCT_rolling
#   - FT_PCT_rolling
#   - AST_TO_RATIO_rolling
#   - EFG_PCT_rolling
#   - TS_PCT_rolling
#   - REB_RATIO_rolling
#   - AST_PCT_rolling
#   - AST_TOV_rolling
#   - OREB_PCT_rolling
#   - DREB_PCT_rolling
#   - REB_PCT_rolling
#   - TM_TOV_PCT_rolling
#
# Cleaning up infinite and NaN values...
# ✅ All derived metrics calculated successfully!

# %%
def prepare_game_data(df):
    """Create game-level dataset with optional home/away differences"""
    # Split into home and away
    home_data = df[df['home_away'] == 'home'].copy()
    away_data = df[df['home_away'] == 'away'].copy()
    
    # Rename columns
    home_data = home_data.rename(columns=lambda x: f"{x}_home" if x not in ['GAME_ID', 'WL', 'GAME_DATE'] else x)
    away_data = away_data.rename(columns=lambda x: f"{x}_away" if x not in ['GAME_ID', 'WL', 'GAME_DATE'] else x)
    
    # Merge home and away data
    game_data = pd.merge(home_data, away_data, on='GAME_ID')
    
    # # Calculate differences only if specified
    # if self.config.calculate_diffs and self.config.difference_columns:
    #     # Get all possible processed column patterns
    #     processed_patterns = []
    #     if self.config.rolling_columns:
    #         processed_patterns.append("_rolling")
    #     if self.config.cumulative_columns:
    #         processed_patterns.append("_cumulative")
        
    #     # Calculate differences for specified columns
    #     for base_col in self.config.difference_columns:
    #         # Check each processing pattern
    #         for pattern in processed_patterns:
    #             col = f"{base_col}{pattern}"
    #             home_col = f'{col}_home'
    #             away_col = f'{col}_away'
    #             if home_col in game_data.columns and away_col in game_data.columns:
    #                 game_data[f'{col}_diff'] = game_data[home_col] - game_data[away_col]
    return game_data

tst = prepare_game_data(final_df)

# %%
initial_elo = 1500
k_factor = 20
home_advantage = 100
elo_width = 400

team_elos = {}

def calculate_elo_probability(home_elo, away_elo):
    """Calculate expected probability of home team winning"""
    return 1.0 / (1 + 10 ** ((away_elo - (home_elo + home_advantage)) / elo_width))

def update_elos(home_team, away_team, home_won, margin):
    """Update Elo ratings for both teams after a game"""
    # Get current Elo ratings (or default if not existing)
    home_elo = team_elos.get(home_team, initial_elo)
    away_elo = team_elos.get(away_team, initial_elo)
    
    # Calculate expected win probability
    expected = calculate_elo_probability(home_elo, away_elo)
    
    # Calculate actual outcome (1 for home win, 0 for home loss)
    actual = float(home_won)
    
    # Optionally, you can use margin to scale Elo change (optional, but common)
    margin_multiplier = max(1, abs(margin) / 10.0)
    elo_change = k_factor * (actual - expected) * margin_multiplier
    
    # Update team Elos
    team_elos[home_team] = home_elo + elo_change
    team_elos[away_team] = away_elo - elo_change
    
    return team_elos[home_team], team_elos[away_team]

def calculate_elo_ratings(df):
    """Calculate Elo ratings for all games"""
    # Reset Elo ratings at start of season
    
    # Sort games chronologically
    df = df.sort_values(['GAME_DATE_x', 'GAME_ID']).copy()
    
    # Create columns for Elo ratings
    df['HOME_ELO_PRE'] = np.nan
    df['AWAY_ELO_PRE'] = np.nan
    df['HOME_ELO_POST'] = np.nan
    df['AWAY_ELO_POST'] = np.nan
    df['HOME_WIN_PROB'] = np.nan
    
    # Keep track of all teams we've seen
    seen_teams = set()
    
    # Process each game
    for idx in df.index:
        home_team = df.loc[idx, 'TEAM_ID_home']
        away_team = df.loc[idx, 'TEAM_ID_away']
        home_score = df.loc[idx, 'PTS_home']
        away_score = df.loc[idx, 'PTS_away']
        margin = home_score - away_score  # <-- This is the margin!
        
        # Check if this is first appearance for either team
        if home_team not in seen_teams:
            team_elos[home_team] = initial_elo
            seen_teams.add(home_team)
        if away_team not in seen_teams:
            team_elos[away_team] = initial_elo
            seen_teams.add(away_team)
            
        # Get pre-game Elos
        home_elo = team_elos[home_team]
        away_elo = team_elos[away_team]
        
        # Store pre-game Elos
        df.loc[idx, 'HOME_ELO_PRE'] = home_elo
        df.loc[idx, 'AWAY_ELO_PRE'] = away_elo
        
        # Calculate win probability
        win_prob = calculate_elo_probability(home_elo, away_elo)
        df.loc[idx, 'HOME_WIN_PROB'] = win_prob
        
        # Update Elos based on game result
        home_won = df.loc[idx, 'WL_x']
        new_home_elo, new_away_elo = update_elos(home_team, away_team, home_won, margin)
        
        # Store post-game Elos
        df.loc[idx, 'HOME_ELO_POST'] = new_home_elo
        df.loc[idx, 'AWAY_ELO_POST'] = new_away_elo
    
    return df

df = calculate_elo_ratings(tst)

# %%
for col in base_columns:
    home = col + "_home"
    away = col + "_away"

    if home in df.columns:
        df.drop(columns=home, inplace=True)

    if away in df.columns:
         df.drop(columns=away, inplace=True)

df = df.drop(columns=['Unnamed: 0_x_home','Unnamed: 0_x_away','SEASON_ID_away','GAME_DATE_y','MATCHUP_away','MATCHUP_home','WL_y','home_away_away','Unnamed: 0_y_away','Unnamed: 0_y_home',
                      'home_away_home'])

df = df.rename(columns={
    'GAME_DATE_x':'GAME_DATE',
    'WL_x':'WL'})

drop_cols = ['FG_PCT','FG3_PCT','FT_PCT']

for col in drop_cols:
    home = col+"_home"
    away = col+"_away"

    if home in df.columns:
        df.drop(columns=home, inplace=True)

    if away in df.columns:
        df.drop(columns=away, inplace=True)

# %%
def get_player_info(player_boxscores, cutoff_date=None, game_id=None, team_id=None, home_away=None):
    """Calculate importance score for each player based on season averages up to cutoff_date"""
    
    # Make a copy to avoid modifying original data
    player_data = player_boxscores.copy()
    
    # Filter by cutoff date for importance calculation (historical data only)
    if cutoff_date is not None:
        historical_data = player_data[player_data['GAME_DATE'] < cutoff_date].copy()
    else:
        historical_data = player_data.copy()
    
    # If no historical data, return zeros
    if historical_data.empty:
        return {
            f'missing_players_{home_away}': 0,
            f'missing_impact_{home_away}': 0.0,
            f'missing_star_{home_away}': False
        }
    
    # Clean minutes column for historical data
    historical_data['MIN'] = historical_data['MIN'].astype(str).str.split('.').str[0]
    historical_data['MIN'] = historical_data['MIN'].fillna(0)
    historical_data['MIN'] = pd.to_numeric(historical_data['MIN'], errors='coerce').fillna(0)
    
    # Calculate season stats from historical data only
    season_stats = historical_data.groupby('PLAYER_ID').agg({
        'MIN': 'mean',
        'PLUS_MINUS': 'mean',
        'PTS': 'mean',
        'AST': 'mean',
        'REB': 'mean',
        'TEAM_ID': 'last'
    }).reset_index()
    
    # Calculate importance scores
    season_stats['importance_score'] = (
        normalize(season_stats['MIN']) * 0.3 +
        normalize(season_stats['PLUS_MINUS']) * 0.2 +
        normalize(season_stats['PTS']) * 0.3 +
        normalize(season_stats['AST'] + season_stats['REB']) * 0.2
    )
    
    # Get players who actually played in this specific game (can look ahead for this)
    game_players = player_data[
        (player_data['GAME_ID'] == game_id) &
        (player_data['TEAM_ID'] == team_id)
    ]['PLAYER_ID'].unique()
    
    # Get team's regular rotation players (from historical data)
    rotation_players = season_stats[
        (season_stats['TEAM_ID'] == team_id) &
        (season_stats['MIN'] >= 15)
    ]['PLAYER_ID'].values
    
    # Find missing players
    missing_players = set(rotation_players) - set(game_players)
    
    # Calculate impact of missing players
    missing_impact = season_stats[
        season_stats['PLAYER_ID'].isin(missing_players)
    ]['importance_score'].sum()
    
    # Check if team's most important player is missing
    team_top_score = season_stats[
        season_stats['TEAM_ID'] == team_id
    ]['importance_score'].max() if not season_stats[season_stats['TEAM_ID'] == team_id].empty else 0
    
    missing_star = False
    if team_top_score > 0:
        missing_star = any(
            season_stats[season_stats['PLAYER_ID'].isin(missing_players)]['importance_score'] >= team_top_score * 0.9
        )
    
    return {
        f'missing_players_{home_away}': len(missing_players),
        f'missing_impact_{home_away}': missing_impact,
        f'missing_star_{home_away}': missing_star
    }

def normalize(series):
    """Normalize a series to 0-1 range"""
    if len(series) == 0:
        return series
    min_val = series.min()
    max_val = series.max()
    if max_val == min_val:
        return series * 0  # Return zeros if all values are the same
    return (series - min_val) / (max_val - min_val)

# Updated processing loop
def process_player_availability(df, player_boxscores_path='player_box_scores_2023.csv'):
    """Process player availability for all games"""
    
    # Load player data once
    bs = pd.read_csv(player_boxscores_path)
    
    # Make sure GAME_DATE is in both dataframes and is datetime
    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
    
    # Add GAME_DATE to player boxscores if not present
    if 'GAME_DATE' not in bs.columns:
        # Extract game dates from your main df
        game_dates = df[['GAME_ID', 'GAME_DATE']].drop_duplicates()
        bs = bs.merge(game_dates, on='GAME_ID', how='left')
    
    bs['GAME_DATE'] = pd.to_datetime(bs['GAME_DATE'])
    
    # Initialize result columns
    df['missing_players_home'] = 0
    df['missing_impact_home'] = 0.0
    df['missing_star_home'] = False
    df['missing_players_away'] = 0
    df['missing_impact_away'] = 0.0
    df['missing_star_away'] = False
    
    # Process each game
    for idx, row in df.iterrows():
        cutoff_date = row['GAME_DATE']
        game_id = row['GAME_ID']
        team_id_home = row['TEAM_ID_home']
        team_id_away = row['TEAM_ID_away']
        
        # Get home team results
        home_results = get_player_info(
            bs, cutoff_date=cutoff_date, game_id=game_id, 
            team_id=team_id_home, home_away='home'
        )
        
        # Get away team results
        away_results = get_player_info(
            bs, cutoff_date=cutoff_date, game_id=game_id, 
            team_id=team_id_away, home_away='away'
        )
        
        # Update dataframe with results for this specific row
        for key, value in home_results.items():
            df.at[idx, key] = value
        
        for key, value in away_results.items():
            df.at[idx, key] = value
    
    return df

# %%
df_with_availability = process_player_availability(df)

# %%
df_with_availability
# Out:
#       SEASON_ID_home  TEAM_ID_home         TEAM_NAME_home   GAME_ID  \
# 245            22023    1610612743         Denver Nuggets  22300061
# 286            22023    1610612744  Golden State Warriors  22300062
# 1189           22023    1610612766      Charlotte Hornets  22300063
# 698            22023    1610612754         Indiana Pacers  22300064
# 616            22023    1610612752        New York Knicks  22300065
# ...              ...           ...                    ...       ...
# 984            22023    1610612760  Oklahoma City Thunder  22301196
# 943            22023    1610612759      San Antonio Spurs  22301197
# 326            22023    1610612744  Golden State Warriors  22301198
# 408            22023    1610612746            LA Clippers  22301199
# 902            22023    1610612758       Sacramento Kings  22301200
#
#       GAME_DATE  WL  FGM_cumulative_home  FGM_rolling_home  \
# 245  2023-10-24   1                  NaN               NaN
# 286  2023-10-24   0                  NaN               NaN
# 1189 2023-10-25   1                  NaN               NaN
# 698  2023-10-25   1                  NaN               NaN
# 616  2023-10-25   0                  NaN               NaN
# ...         ...  ..                  ...               ...
# 984  2024-04-14   1               3599.0              44.0
# 943  2024-04-14   1               3389.0              41.0
# 326  2024-04-14   1               3537.0              42.6
# 408  2024-04-14   0               3432.0              44.0
# 902  2024-04-14   1               3510.0              39.4
#
#       FGA_cumulative_home  FGA_rolling_home  ...  HOME_ELO_POST  \
# 245                   NaN               NaN  ...    1508.638440
# 286                   NaN               NaN  ...    1487.198700
# 1189                  NaN               NaN  ...    1507.198700
# 698                   NaN               NaN  ...    1516.557010
# 616                   NaN               NaN  ...    1487.198700
# ...                   ...               ...  ...            ...
# 984                7227.0              88.6  ...    1694.313857
# 943                7345.0              89.8  ...    1386.928833
# 326                7421.0              85.6  ...    1639.894492
# 408                7004.0              90.6  ...    1549.118558
# 902                7368.0              92.8  ...    1552.942853
#
#       AWAY_ELO_POST  HOME_WIN_PROB  missing_players_home  missing_impact_home  \
# 245     1491.361560       0.640065                     0             0.000000
# 286     1512.801300       0.640065                     0             0.000000
# 1189    1492.801300       0.640065                     0             0.000000
# 698     1483.442990       0.640065                     0             0.000000
# 616     1512.801300       0.640065                     0             0.000000
# ...             ...            ...                   ...                  ...
# 984     1633.195455       0.622941                     0             0.000000
# 943     1236.294203       0.786719                     5             2.614281
# 326     1343.797948       0.905366                     2             1.233664
# 408     1524.005988       0.711010                     4             2.675073
# 902     1277.658038       0.886822                     2             1.016280
#
#       missing_star_home  missing_players_away  missing_impact_away  \
# 245               False                     0             0.000000
# 286               False                     0             0.000000
# 1189              False                     0             0.000000
# 698               False                     0             0.000000
# 616               False                     0             0.000000
# ...                 ...                   ...                  ...
# 984               False                     6             3.586894
# 943                True                     6             2.374457
# 326                True                     6             3.132107
# 408                True                     4             2.416237
# 902               False                     7             3.225441
#
#       missing_star_away  WIN
# 245               False    1
# 286               False    0
# 1189              False    1
# 698               False    1
# 616               False    0
# ...                 ...  ...
# 984                True    1
# 943               False    1
# 326                True    1
# 408                True    0
# 902                True    1
#
# [1230 rows x 180 columns]

# %%
df = df_with_availability.copy()

# %%
df['WIN'] = (df['WL'] == 1).astype(int)
df['missing_star_away'] = df['missing_star_away'].map({True: 1, False: 0})
df['missing_star_home'] = df['missing_star_home'].map({True: 1, False: 0})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

t = df.dropna()
# get only the numeric columns
numeric_cols = t.select_dtypes(include=['float64', 'int64'])
numeric_cols = numeric_cols.drop(columns=['GAME_ID', 'TEAM_ID_home', 'TEAM_ID_away','SEASON_ID_home','WL'])

corr = t[numeric_cols].corr()
corr_with_win = corr[['WIN']].sort_values(by='WIN', ascending=False)

# plt.figure(figsize=(8, 12))  # Wider for readability
# sns.heatmap(corr_with_win, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title("Correlation with WIN (Home Team Victory)")
# plt.tight_layout()
# plt.show()

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Remove columns you don't want (if needed)
drop_cols = ['GAME_ID', 'TEAM_ID_home', 'TEAM_ID_away', 'SEASON_ID_home', 'WL']
numeric_cols = [col for col in numeric_cols if col not in drop_cols]

# Calculate correlation with WIN
correlations = df[numeric_cols].corrwith(df['WIN']).sort_values(ascending=False)

# Display as a table
correlations
# Out:
# WIN                             1.000000
# HOME_ELO_POST                   0.380479
# HOME_WIN_PROB                   0.356180
# HOME_ELO_PRE                    0.280791
# PLUS_MINUS_cumulative_home      0.268540
#                                   ...
# NET_RATING_cumulative_away     -0.217411
# E_NET_RATING_cumulative_away   -0.218879
# PLUS_MINUS_cumulative_away     -0.219052
# AWAY_ELO_PRE                   -0.235329
# AWAY_ELO_POST                  -0.335873
# Length: 172, dtype: float64

# %%
# ----- 1.  Specify base column names for rolling stats ------------------------
# Only include the **root** of each feature; the suffixes "_home" / "_away"
# and "_rolling" are added automatically below.
rolling_basenames = [
    # Team strength & efficiency
    "NET_RATING", "OFF_RATING", "DEF_RATING",
    "E_NET_RATING", "E_OFF_RATING", "E_DEF_RATING",
    "PIE",

    # Shooting efficiency
    "FG_PCT", "FG3_PCT", "FT_PCT", "EFG_PCT", "TS_PCT",

    # Possession & tempo
    "PACE", "E_PACE", "PACE_PER40", "POSS",

    # Ball movement & turnovers
    "AST_TO_RATIO", "AST_PCT", "AST_TOV", "TM_TOV_PCT",

    # Rebounding
    "OREB_PCT", "DREB_PCT", "REB_PCT", "REB_RATIO",

    # Game control
    "PLUS_MINUS", "PTS"
]

# ----- 2.  Build diff features and collect columns to drop -------------------
cols_to_drop = []          # keep track of original cols we’ll remove

for base in rolling_basenames:
    home_col = f"{base}_rolling_home"
    away_col = f"{base}_rolling_away"
    diff_col = f"{base}_diff"

    # Skip if either column is missing (protects against typos / schema drift)
    if home_col in df.columns and away_col in df.columns:
        df[diff_col] = df[home_col] - df[away_col]
        cols_to_drop.extend([home_col, away_col])
    else:
        print(f"⚠️  Skipping {base}: expected columns not found.")

# ----- 3.  Add ELO diff (pre-game) -------------------------------------------
elo_pairs = [
    ("HOME_ELO_PRE", "AWAY_ELO_PRE", "ELO_DIFF"),   # pre-game
    ("HOME_ELO_POST", "AWAY_ELO_POST", "ELO_POST_DIFF")  # optional
]

for home_col, away_col, diff_col in elo_pairs:
    if home_col in df.columns and away_col in df.columns:
        df[diff_col] = df[home_col] - df[away_col]
        cols_to_drop.extend([home_col, away_col])
    else:
        print(f"⚠️  Skipping ELO pair: {home_col}, {away_col} not found.")

# ----- 4.  Drop the original home/away columns --------------------------------
df.drop(columns=cols_to_drop, inplace=True)

# %%
df
# Out:
#       SEASON_ID_home  TEAM_ID_home         TEAM_NAME_home   GAME_ID  \
# 245            22023    1610612743         Denver Nuggets  22300061
# 286            22023    1610612744  Golden State Warriors  22300062
# 1189           22023    1610612766      Charlotte Hornets  22300063
# 698            22023    1610612754         Indiana Pacers  22300064
# 616            22023    1610612752        New York Knicks  22300065
# ...              ...           ...                    ...       ...
# 984            22023    1610612760  Oklahoma City Thunder  22301196
# 943            22023    1610612759      San Antonio Spurs  22301197
# 326            22023    1610612744  Golden State Warriors  22301198
# 408            22023    1610612746            LA Clippers  22301199
# 902            22023    1610612758       Sacramento Kings  22301200
#
#       GAME_DATE  WL  FGM_cumulative_home  FGM_rolling_home  \
# 245  2023-10-24   1                  NaN               NaN
# 286  2023-10-24   0                  NaN               NaN
# 1189 2023-10-25   1                  NaN               NaN
# 698  2023-10-25   1                  NaN               NaN
# 616  2023-10-25   0                  NaN               NaN
# ...         ...  ..                  ...               ...
# 984  2024-04-14   1               3599.0              44.0
# 943  2024-04-14   1               3389.0              41.0
# 326  2024-04-14   1               3537.0              42.6
# 408  2024-04-14   0               3432.0              44.0
# 902  2024-04-14   1               3510.0              39.4
#
#       FGA_cumulative_home  FGA_rolling_home  ...  AST_TOV_diff  \
# 245                   NaN               NaN  ...           NaN
# 286                   NaN               NaN  ...           NaN
# 1189                  NaN               NaN  ...           NaN
# 698                   NaN               NaN  ...           NaN
# 616                   NaN               NaN  ...           NaN
# ...                   ...               ...  ...           ...
# 984                7227.0              88.6  ...      0.331551
# 943                7345.0              89.8  ...     -0.017453
# 326                7421.0              85.6  ...      0.377949
# 408                7004.0              90.6  ...     -0.895928
# 902                7368.0              92.8  ...      0.566138
#
#       TM_TOV_PCT_diff  OREB_PCT_diff  DREB_PCT_diff  REB_PCT_diff  \
# 245               NaN            NaN            NaN           NaN
# 286               NaN            NaN            NaN           NaN
# 1189              NaN            NaN            NaN           NaN
# 698               NaN            NaN            NaN           NaN
# 616               NaN            NaN            NaN           NaN
# ...               ...            ...            ...           ...
# 984         -0.020692      -0.015550      -0.021333     -0.036883
# 943          0.028655       0.009389       0.059696      0.069085
# 326          0.004526      -0.027616       0.065827      0.038211
# 408          0.053360       0.019763       0.077075      0.096838
# 902         -0.034723      -0.055634       0.005324     -0.050311
#
#       REB_RATIO_diff  PLUS_MINUS_diff  PTS_diff    ELO_DIFF  ELO_POST_DIFF
# 245              NaN              NaN       NaN    0.000000      17.276880
# 286              NaN              NaN       NaN    0.000000     -25.602600
# 1189             NaN              NaN       NaN    0.000000      14.397400
# 698              NaN              NaN       NaN    0.000000      33.114020
# 616              NaN              NaN       NaN    0.000000     -25.602600
# ...              ...              ...       ...         ...            ...
# 984        -0.029446              2.4       2.4  -12.785235      61.118402
# 943        -0.014264              4.6       8.4  126.747178     150.634629
# 326        -0.143297             14.4       5.2  292.311192     296.096545
# 408        -0.011642              7.0      -4.4   56.397002      25.112571
# 902        -0.168449              9.4       5.6  257.628974     275.284814
#
# [1230 rows x 152 columns]

# %%
import pandas as pd
df = pd.read_csv('final_preprocessed_data.csv')
df
# Out:
#       SEASON_ID_home  TEAM_ID_home         TEAM_NAME_home   GAME_ID  \
# 0              22023    1610612743         Denver Nuggets  22300061
# 1              22023    1610612744  Golden State Warriors  22300062
# 2              22023    1610612766      Charlotte Hornets  22300063
# 3              22023    1610612754         Indiana Pacers  22300064
# 4              22023    1610612752        New York Knicks  22300065
# ...              ...           ...                    ...       ...
# 1225           22023    1610612760  Oklahoma City Thunder  22301196
# 1226           22023    1610612759      San Antonio Spurs  22301197
# 1227           22023    1610612744  Golden State Warriors  22301198
# 1228           22023    1610612746            LA Clippers  22301199
# 1229           22023    1610612758       Sacramento Kings  22301200
#
#        GAME_DATE  WL  FGM_cumulative_home  FGM_rolling_home  \
# 0     2023-10-24   1                  NaN               NaN
# 1     2023-10-24   0                  NaN               NaN
# 2     2023-10-25   1                  NaN               NaN
# 3     2023-10-25   1                  NaN               NaN
# 4     2023-10-25   0                  NaN               NaN
# ...          ...  ..                  ...               ...
# 1225  2024-04-14   1               3599.0              44.0
# 1226  2024-04-14   1               3389.0              41.0
# 1227  2024-04-14   1               3537.0              42.6
# 1228  2024-04-14   0               3432.0              44.0
# 1229  2024-04-14   1               3510.0              39.4
#
#       FGA_cumulative_home  FGA_rolling_home  ...  HOME_ELO_POST  \
# 0                     NaN               NaN  ...    1508.638440
# 1                     NaN               NaN  ...    1487.198700
# 2                     NaN               NaN  ...    1507.198700
# 3                     NaN               NaN  ...    1516.557010
# 4                     NaN               NaN  ...    1487.198700
# ...                   ...               ...  ...            ...
# 1225               7227.0              88.6  ...    1694.313857
# 1226               7345.0              89.8  ...    1386.928833
# 1227               7421.0              85.6  ...    1639.894492
# 1228               7004.0              90.6  ...    1549.118558
# 1229               7368.0              92.8  ...    1552.942853
#
#       AWAY_ELO_POST  HOME_WIN_PROB  missing_players_home  missing_impact_home  \
# 0       1491.361560       0.640065                     0             0.000000
# 1       1512.801300       0.640065                     0             0.000000
# 2       1492.801300       0.640065                     0             0.000000
# 3       1483.442990       0.640065                     0             0.000000
# 4       1512.801300       0.640065                     0             0.000000
# ...             ...            ...                   ...                  ...
# 1225    1633.195455       0.622941                     0             0.000000
# 1226    1236.294203       0.786719                     5             2.614281
# 1227    1343.797948       0.905366                     2             1.233664
# 1228    1524.005988       0.711010                     4             2.675073
# 1229    1277.658038       0.886822                     2             1.016280
#
#       missing_star_home  missing_players_away  missing_impact_away  \
# 0                     0                     0             0.000000
# 1                     0                     0             0.000000
# 2                     0                     0             0.000000
# 3                     0                     0             0.000000
# 4                     0                     0             0.000000
# ...                 ...                   ...                  ...
# 1225                  0                     6             3.586894
# 1226                  1                     6             2.374457
# 1227                  1                     6             3.132107
# 1228                  1                     4             2.416237
# 1229                  0                     7             3.225441
#
#       missing_star_away  WIN
# 0                     0    1
# 1                     0    0
# 2                     0    1
# 3                     0    1
# 4                     0    0
# ...                 ...  ...
# 1225                  1    1
# 1226                  0    1
# 1227                  1    1
# 1228                  1    0
# 1229                  1    1
#
# [1230 rows x 180 columns]

# %%
df.columns
# Out:
# Index(['SEASON_ID_home', 'TEAM_ID_home', 'TEAM_NAME_home', 'GAME_ID',
#        'GAME_DATE', 'WL', 'FGM_cumulative_home', 'FGM_rolling_home',
#        'FGA_cumulative_home', 'FGA_rolling_home',
#        ...
#        'HOME_ELO_POST', 'AWAY_ELO_POST', 'HOME_WIN_PROB',
#        'missing_players_home', 'missing_impact_home', 'missing_star_home',
#        'missing_players_away', 'missing_impact_away', 'missing_star_away',
#        'WIN'],
#       dtype='object', length=180)

# %%
df = df.drop(columns=[
'SEASON_ID_home', 'TEAM_ID_home', 'TEAM_NAME_home', 'GAME_ID','GAME_DATE', 'TEAM_ID_away','TEAM_NAME_away','HOME_ELO_POST','AWAY_ELO_POST','WL'])

# %%
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X = df.drop(columns=['WIN'])
y = df['WIN']
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42, test_size=0.2)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

from sklearn.linear_model import LassoCV

lasso = LassoCV(alphas=[0.1, 0.01, 0.001, 0.0001], cv=5, random_state=42)
lasso.fit(X_train_scaled, y_train)
# Out:
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5503454751155346, tolerance: 0.019380952380952398
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.962960902023674, tolerance: 0.019380952380952398
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28031091498334604, tolerance: 0.019320463320463273
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.55673295785201, tolerance: 0.019320463320463273
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.491638493768363, tolerance: 0.0192643958868895
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.17136848376806, tolerance: 0.0192643958868895
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.014902626900607, tolerance: 0.01936966580976869
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.30946924831163, tolerance: 0.01936966580976869
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4951274624594362, tolerance: 0.01933431876606677
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.82316806289168, tolerance: 0.01933431876606677
#   model = cd_fast.enet_coordinate_descent_gram(
# LassoCV(alphas=[0.1, 0.01, 0.001, 0.0001], cv=5, random_state=42)

# %%
# Print the best alpha found by LassoCV
print("Best alpha using built-in LassoCV:", lasso.alpha_)

# Display coefficients
lasso_coefficients = pd.Series(lasso.coef_, index=X_train.columns)
# print("LASSO Coefficients:\n", lasso_coefficients.sort_values())

lasso_coefficients[lasso_coefficients > 0].sort_values(ascending=False)
# Out:
# Best alpha using built-in LassoCV: 0.01
# HOME_WIN_PROB                 0.119201
# DREB_PCT_cumulative_home      0.022167
# OFF_RATING_rolling_home       0.018525
# AST_rolling_away              0.013236
# missing_impact_away           0.011497
# PLUS_MINUS_cumulative_home    0.007612
# REB_RATIO_cumulative_away     0.005591
# missing_star_away             0.005114
# AST_PCT_cumulative_away       0.003437
# AST_TO_RATIO_rolling_away     0.001735
# AST_TOV_rolling_away          0.000425
# TS_PCT_cumulative_home        0.000003
# dtype: float64

# %%
# Perform PCA on the scaled training data
from sklearn.decomposition import PCA

# Choose the number of components (e.g., enough to explain 95% variance)
pca = PCA(n_components=0.95, random_state=42)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print(f"Number of PCA components to explain 95% variance: {pca.n_components_}")

# Optionally, view explained variance ratio
explained_var = pd.Series(pca.explained_variance_ratio_)
print("Explained variance ratio per component:")
print(explained_var)

# If you want to see the loadings (feature importance for each component)
loadings = pd.DataFrame(pca.components_.T, index=X_train.columns, columns=[f'PC{i+1}' for i in range(pca.n_components_)])
loadings
# Out:
# Number of PCA components to explain 95% variance: 32
# Explained variance ratio per component:
# 0     0.302539
# 1     0.102705
# 2     0.094931
# 3     0.046137
# 4     0.045269
# 5     0.032602
# 6     0.030813
# 7     0.029207
# 8     0.026298
# 9     0.021473
# 10    0.020344
# 11    0.019256
# 12    0.018194
# 13    0.015087
# 14    0.013766
# 15    0.012534
# 16    0.011958
# 17    0.011417
# 18    0.010507
# 19    0.009347
# 20    0.008956
# 21    0.008102
# 22    0.007851
# 23    0.007518
# 24    0.007185
# 25    0.006744
# 26    0.006347
# 27    0.005535
# 28    0.005193
# 29    0.004912
# 30    0.004832
# 31    0.004335
# dtype: float64
#                            PC1       PC2       PC3       PC4       PC5  \
# FGM_cumulative_home  -0.138982 -0.014458  0.000226 -0.003754 -0.004669
# FGM_rolling_home      0.001828  0.003172  0.185100 -0.098309 -0.062931
# FGA_cumulative_home  -0.139001 -0.014359 -0.011219 -0.002943 -0.001810
# FGA_rolling_home      0.016136  0.007234  0.018555 -0.082750 -0.015194
# FG3M_cumulative_home -0.137113 -0.016017  0.006664  0.002290  0.002686
# ...                        ...       ...       ...       ...       ...
# missing_impact_home  -0.044174 -0.005036 -0.088307 -0.003844  0.006747
# missing_star_home    -0.033670 -0.003938 -0.072114  0.007526 -0.001567
# missing_players_away -0.038898 -0.112075 -0.009148 -0.001849  0.007873
# missing_impact_away  -0.039711 -0.101245 -0.006156  0.006430  0.000688
# missing_star_away    -0.025787 -0.071279  0.000192  0.009304  0.002964
#
#                            PC6       PC7       PC8       PC9      PC10  ...  \
# FGM_cumulative_home   0.006379 -0.015460  0.018055  0.004233  0.004225  ...
# FGM_rolling_home     -0.053740 -0.090155  0.105373 -0.098656 -0.054613  ...
# FGA_cumulative_home   0.001904 -0.014650  0.020305  0.001710 -0.004180  ...
# FGA_rolling_home     -0.232629 -0.207202  0.140453 -0.083125  0.146905  ...
# FG3M_cumulative_home -0.013964 -0.017774  0.013505  0.011901  0.004421  ...
# ...                        ...       ...       ...       ...       ...  ...
# missing_impact_home   0.002356  0.063459 -0.061358  0.017308 -0.065917  ...
# missing_star_home    -0.000016  0.071050 -0.068464  0.020085 -0.082784  ...
# missing_players_away -0.024859 -0.027550 -0.044362 -0.039125 -0.044296  ...
# missing_impact_away  -0.036717 -0.013720 -0.050024 -0.060916 -0.042987  ...
# missing_star_away    -0.035684 -0.012585 -0.052720 -0.054974 -0.007291  ...
#
#                           PC23      PC24      PC25      PC26      PC27  \
# FGM_cumulative_home   0.006746 -0.001860  0.001903 -0.005889 -0.003960
# FGM_rolling_home     -0.002589  0.004079 -0.063497 -0.252314 -0.035018
# FGA_cumulative_home   0.006994 -0.001671  0.004664 -0.001342 -0.006970
# FGA_rolling_home     -0.084756  0.006129 -0.056166 -0.175647 -0.032550
# FG3M_cumulative_home  0.012059  0.004080  0.004166  0.014815 -0.000446
# ...                        ...       ...       ...       ...       ...
# missing_impact_home  -0.064484  0.137131 -0.012825  0.035972  0.037630
# missing_star_home    -0.069031  0.173618 -0.022983  0.015070 -0.035428
# missing_players_away -0.159850 -0.065986 -0.031726  0.033527 -0.032529
# missing_impact_away  -0.165671 -0.083666 -0.073666  0.039270 -0.021758
# missing_star_away    -0.154521 -0.096316 -0.137276  0.067084 -0.010346
#
#                           PC28      PC29      PC30      PC31      PC32
# FGM_cumulative_home   0.003123 -0.000062 -0.005929 -0.003466  0.014380
# FGM_rolling_home      0.124337 -0.130911  0.008123  0.061664  0.088476
# FGA_cumulative_home  -0.001334  0.003940  0.001916 -0.003394  0.010171
# FGA_rolling_home      0.024663 -0.117231 -0.072592  0.086891  0.004490
# FG3M_cumulative_home -0.012345  0.013977  0.003594 -0.000720  0.017749
# ...                        ...       ...       ...       ...       ...
# missing_impact_home   0.053791  0.004485  0.071312  0.017938  0.038404
# missing_star_home     0.151203  0.043885 -0.220346 -0.083342  0.040328
# missing_players_away -0.078477  0.050659  0.039061 -0.029541  0.089048
# missing_impact_away  -0.062418  0.104569  0.033520 -0.013436  0.056363
# missing_star_away     0.021885  0.186270 -0.019928  0.071534 -0.219794
#
# [169 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Project the training data onto the first two principal components
pc1 = X_train_pca[:, 0]
pc2 = X_train_pca[:, 1]

# Color by win/loss
colors = np.where(y_train.values == 1, 'royalblue', 'orangered')
labels = np.where(y_train.values == 1, 'Win', 'Loss')

plt.figure(figsize=(10, 8))
scatter = plt.scatter(pc1, pc2, c=colors, alpha=0.4, label=None)

# Plot feature vectors (loadings)
scale = 1
for i, feature in enumerate(X_train.columns):
    plt.arrow(0, 0, 
              loadings.iloc[i, 0]*scale,  # scale for visibility
              loadings.iloc[i, 1]*scale, 
              color='gray', alpha=0.5)
    plt.text(loadings.iloc[i, 0]*scale, 
             loadings.iloc[i, 1]*scale, 
             feature, color='green', ha='center', va='center', fontsize=8)

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA Biplot (colored by Win/Loss)')
plt.grid(True)

# Custom legend
from matplotlib.lines import Line2D
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Win', markerfacecolor='royalblue', markersize=10, alpha=0.6),
    Line2D([0], [0], marker='o', color='w', label='Loss', markerfacecolor='orangered', markersize=10, alpha=0.6)
]
plt.legend(handles=legend_elements, title='Game Result')
plt.tight_layout()
plt.show()

# %%
# Show the loadings (feature weights) for PC1 and PC2
loadings[['PC1', 'PC2']].sort_values(by='PC1', ascending=False)
# Out:
#                                    PC1       PC2
# PF_rolling_away               0.059415 -0.017918
# PF_rolling_home               0.059317  0.000281
# E_PACE_rolling_home           0.055684  0.010282
# E_PACE_rolling_away           0.049174  0.022105
# PACE_rolling_home             0.049093  0.011656
# ...                                ...       ...
# E_OFF_RATING_cumulative_home -0.139147 -0.015548
# OFF_RATING_cumulative_home   -0.139151 -0.015544
# PTS_cumulative_away          -0.139159 -0.003848
# OFF_RATING_cumulative_away   -0.139273 -0.004201
# E_OFF_RATING_cumulative_away -0.139278 -0.003702
#
# [169 rows x 2 columns]

# %%
# Sort by absolute value of loadings for PC1
loadings[['PC1', 'PC2']].reindex(loadings['PC1'].abs().sort_values(ascending=False).index)
# Out:
#                                    PC1       PC2
# E_OFF_RATING_cumulative_away -0.139278 -0.003702
# OFF_RATING_cumulative_away   -0.139273 -0.004201
# PTS_cumulative_away          -0.139159 -0.003848
# OFF_RATING_cumulative_home   -0.139151 -0.015544
# E_OFF_RATING_cumulative_home -0.139147 -0.015548
# ...                                ...       ...
# BLK_rolling_away              0.000806  0.060101
# REB_RATIO_cumulative_home     0.000769  0.008123
# FGM_rolling_away             -0.000416  0.179553
# FG3A_rolling_away             0.000369  0.029497
# DEF_RATING_rolling_home      -0.000266  0.008932
#
# [169 rows x 2 columns]

# %%
# --- 1. Import libraries ---
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
import xgboost as xgb

# --- 2. Fit Logistic Regression ---
logreg = LogisticRegression(random_state=42, max_iter=1000)
logreg.fit(X_train_pca, y_train)
y_pred_logreg = logreg.predict(X_test_pca)
y_proba_logreg = logreg.predict_proba(X_test_pca)[:, 1]

# --- 3. Fit SVM (with probability for ROC AUC) ---
svm = SVC(kernel='rbf', probability=True, random_state=42)
svm.fit(X_train_pca, y_train)
y_pred_svm = svm.predict(X_test_pca)
y_proba_svm = svm.predict_proba(X_test_pca)[:, 1]

# --- 4. Fit XGBoost ---
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train_pca, y_train)
y_pred_xgb = xgb_model.predict(X_test_pca)
y_proba_xgb = xgb_model.predict_proba(X_test_pca)[:, 1]

# --- 5. Compare Results ---
def print_metrics(name, y_true, y_pred, y_proba):
    print(f"\n{name} Results:")
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("ROC AUC:", roc_auc_score(y_true, y_proba))
    print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
    print("Classification Report:\n", classification_report(y_true, y_pred))

print_metrics("Logistic Regression", y_test, y_pred_logreg, y_proba_logreg)
print_metrics("SVM", y_test, y_pred_svm, y_proba_svm)
print_metrics("XGBoost", y_test, y_pred_xgb, y_proba_xgb)
# Out:
# Logistic Regression Results:
# Accuracy: 0.6748971193415638
# ROC AUC: 0.7300774764803543
# Confusion Matrix:
#  [[ 60  44]
#  [ 35 104]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.58      0.60       104
#            1       0.70      0.75      0.72       139
#
#     accuracy                           0.67       243
#    macro avg       0.67      0.66      0.66       243
# weighted avg       0.67      0.67      0.67       243
#
#
# SVM Results:
# Accuracy: 0.654320987654321
# ROC AUC: 0.7031682346430549
# Confusion Matrix:
#  [[61 43]
#  [41 98]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.59      0.59       104
#            1       0.70      0.71      0.70       139
#
#     accuracy                           0.65       243
#    macro avg       0.65      0.65      0.65       243
# weighted avg       0.65      0.65      0.65       243
#
#
# XGBoost Results:
# Accuracy: 0.6625514403292181
# ROC AUC: 0.7016463752075263
# Confusion Matrix:
#  [[65 39]
#  [43 96]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.62      0.61       104
#            1       0.71      0.69      0.70       139
#
#     accuracy                           0.66       243
#    macro avg       0.66      0.66      0.66       243
# weighted avg       0.66      0.66      0.66       243
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [00:59:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.model_selection import GridSearchCV

# --- Fine-tune SVM ---
svm_params = {
    'C': [0.01, 0.1, 1, 10, 100],
    'gamma': ['scale', 0.01, 0.1, 1, 10],
    'kernel': ['rbf', 'linear']
}
svm_grid = GridSearchCV(SVC(probability=True, random_state=42), svm_params, cv=5, scoring='roc_auc', n_jobs=-1)
svm_grid.fit(X_train_pca, y_train)
print("Best SVM params:", svm_grid.best_params_)
print("Best SVM CV ROC AUC:", svm_grid.best_score_)

# Evaluate best SVM
best_svm = svm_grid.best_estimator_
y_pred_svm_tuned = best_svm.predict(X_test_pca)
y_proba_svm_tuned = best_svm.predict_proba(X_test_pca)[:, 1]

print_metrics("Tuned SVM", y_test, y_pred_svm_tuned, y_proba_svm_tuned)

# --- Fine-tune XGBoost ---
xgb_params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [2, 3, 4, 5],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.7, 1.0],
    'colsample_bytree': [0.7, 1.0]
}
xgb_grid = GridSearchCV(
    xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    xgb_params, cv=5, scoring='roc_auc', n_jobs=-1
)
xgb_grid.fit(X_train_pca, y_train)
print("Best XGBoost params:", xgb_grid.best_params_)
print("Best XGBoost CV ROC AUC:", xgb_grid.best_score_)

# Evaluate best XGBoost
best_xgb = xgb_grid.best_estimator_
y_pred_xgb_tuned = best_xgb.predict(X_test_pca)
# Out:
# Best SVM params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Best SVM CV ROC AUC: 0.7039552612629535
#
# Tuned SVM Results:
# Accuracy: 0.654320987654321
# ROC AUC: 0.7031682346430549
# Confusion Matrix:
#  [[61 43]
#  [41 98]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.59      0.59       104
#            1       0.70      0.71      0.70       139
#
#     accuracy                           0.65       243
#    macro avg       0.65      0.65      0.65       243
# weighted avg       0.65      0.65      0.65       243
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best XGBoost params: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.7}
# Best XGBoost CV ROC AUC: 0.6925425471963933
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:03:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# --- Fit and compare models WITHOUT PCA ---

# Logistic Regression
logreg_raw = LogisticRegression(random_state=42, max_iter=1000)
logreg_raw.fit(X_train_scaled, y_train)
y_pred_logreg_raw = logreg_raw.predict(X_test_scaled)
y_proba_logreg_raw = logreg_raw.predict_proba(X_test_scaled)[:, 1]

# SVM
svm_raw = SVC(kernel='rbf', probability=True, random_state=42)
svm_raw.fit(X_train_scaled, y_train)
y_pred_svm_raw = svm_raw.predict(X_test_scaled)
y_proba_svm_raw = svm_raw.predict_proba(X_test_scaled)[:, 1]

# XGBoost
xgb_raw = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_raw.fit(X_train_scaled, y_train)
y_pred_xgb_raw = xgb_raw.predict(X_test_scaled)
y_proba_xgb_raw = xgb_raw.predict_proba(X_test_scaled)[:, 1]

# Compare results
print_metrics("Logistic Regression (raw features)", y_test, y_pred_logreg_raw, y_proba_logreg_raw)
print_metrics("SVM (raw features)", y_test, y_pred_svm_raw, y_proba_svm_raw)
print_metrics("XGBoost (raw features)", y_test, y_pred_xgb_raw, y_proba_xgb_raw)
# Out:
# /Users/nicholashorton/miniconda3/envs/myenv/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [01:08:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Logistic Regression (raw features) Results:
# Accuracy: 0.6666666666666666
# ROC AUC: 0.7232982844493635
# Confusion Matrix:
#  [[70 34]
#  [47 92]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63       104
#            1       0.73      0.66      0.69       139
#
#     accuracy                           0.67       243
#    macro avg       0.66      0.67      0.66       243
# weighted avg       0.67      0.67      0.67       243
#
#
# SVM (raw features) Results:
# Accuracy: 0.6625514403292181
# ROC AUC: 0.7061427780852241
# Confusion Matrix:
#  [[63 41]
#  [41 98]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       104
#            1       0.71      0.71      0.71       139
#
#     accuracy                           0.66       243
#    macro avg       0.66      0.66      0.66       243
# weighted avg       0.66      0.66      0.66       243
#
#
# XGBoost (raw features) Results:
# Accuracy: 0.6872427983539094
# ROC AUC: 0.7159656889872716
# Confusion Matrix:
#  [[ 67  37]
#  [ 39 100]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64       104
#            1       0.73      0.72      0.72       139
#
#     accuracy                           0.69       243
#    macro avg       0.68      0.68      0.68       243
# weighted avg       0.69      0.69      0.69       243

# %%
from sklearn.ensemble import RandomForestClassifier

# --- SVM with different kernels ---
svm_kernel_params = {
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}
svm_kernel_grid = GridSearchCV(
    SVC(probability=True, random_state=42),
    svm_kernel_params, cv=5, scoring='roc_auc', n_jobs=-1
)
svm_kernel_grid.fit(X_train_scaled, y_train)
print("Best SVM kernel params:", svm_kernel_grid.best_params_)
print("Best SVM kernel CV ROC AUC:", svm_kernel_grid.best_score_)

best_svm_kernel = svm_kernel_grid.best_estimator_
y_pred_svm_kernel = best_svm_kernel.predict(X_test_scaled)
y_proba_svm_kernel = best_svm_kernel.predict_proba(X_test_scaled)[:, 1]
print_metrics("SVM (best kernel, raw features)", y_test, y_pred_svm_kernel, y_proba_svm_kernel)

# --- Random Forest with hyperparameter tuning ---
rf_params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10, 20],
    'max_features': ['sqrt', 'log2', None]
}
rf_grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    rf_params, cv=5, scoring='roc_auc', n_jobs=-1
)
rf_grid.fit(X_train_scaled, y_train)
print("Best RF params:", rf_grid.best_params_)
print("Best RF CV ROC AUC:", rf_grid.best_score_)

best_rf = rf_grid.best_estimator_
y_pred_rf = best_rf.predict(X_test_scaled)
y_proba_rf = best_rf.predict_proba(X_test_scaled)[:, 1]
print_metrics("Random Forest (raw features)", y_test, y_pred_rf, y_proba_rf)
# Out:
# Best SVM kernel params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Best SVM kernel CV ROC AUC: 0.7017895494818571
#
# SVM (best kernel, raw features) Results:
# Accuracy: 0.6625514403292181
# ROC AUC: 0.7061427780852241
# Confusion Matrix:
#  [[63 41]
#  [41 98]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       104
#            1       0.71      0.71      0.71       139
#
#     accuracy                           0.66       243
#    macro avg       0.66      0.66      0.66       243
# weighted avg       0.66      0.66      0.66       243
#
# Best RF params: {'max_depth': 5, 'max_features': None, 'n_estimators': 100}
# Best RF CV ROC AUC: 0.6996621427006042
#
# Random Forest (raw features) Results:
# Accuracy: 0.6625514403292181
# ROC AUC: 0.7093248478140565
# Confusion Matrix:
#  [[ 57  47]
#  [ 35 104]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.55      0.58       104
#            1       0.69      0.75      0.72       139
#
#     accuracy                           0.66       243
#    macro avg       0.65      0.65      0.65       243
# weighted avg       0.66      0.66      0.66       243

# %%
# --- Baseline 1: Always predict home team wins ---
always_home_pred = [1] * len(y_test)
print("Baseline (Always Home Wins) Accuracy:", accuracy_score(y_test, always_home_pred))

# --- Baseline 2: Predict team with higher ELO wins ---
# Get the indices of the test set in the original dataframe
test_indices = y_test.index

# You need the ELO columns from the original dataframe (not scaled)
# If you dropped them, reload or merge them back for this calculation
# Assuming you have a dataframe 'df_with_elo' with 'HOME_ELO_PRE' and 'AWAY_ELO_PRE'
# If not, you may need to reload your data or use the original df before dropping columns

# Example using the original df (before dropping ELO columns):
# elo_pred = (df.loc[test_indices, 'HOME_ELO_PRE'] > df.loc[test_indices, 'AWAY_ELO_PRE']).astype(int).values

# If you have dropped those columns, reload the data:
import pandas as pd
df_elo = df.copy()
elo_pred = (df_elo.loc[test_indices, 'HOME_ELO_PRE'] > df_elo.loc[test_indices, 'AWAY_ELO_PRE']).astype(int).values
elo_true = df_elo.loc[test_indices, 'WIN'].values

print("Baseline (Higher ELO Wins) Accuracy:", accuracy_score(elo_true, elo_pred))
# Out:
# Baseline (Always Home Wins) Accuracy: 0.5720164609053497
# Baseline (Higher ELO Wins) Accuracy: 0.6255144032921811
